# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Concatenate, BatchNormalization, ReLU, LeakyReLU, Add
from tensorflow.keras.models import Model

# %%
# Define image dimensions
IMG_HEIGHT = 256
IMG_WIDTH = 8192  # 4096 * 2
CHANNELS = 1

# Paths to the directories containing images
lhsa_kanjur_path = '/Resized_Selected_LG'
computer_font_path = '/Resized_Selected_Comp'

def load_images_from_folder(folder, img_height, img_width, channels):
    images = []
    for filename in sorted(os.listdir(folder)):
        file_path = os.path.join(folder, filename)
        if os.path.isdir(file_path):
            continue  # Skip directories
        try:
            img = load_img(file_path, color_mode='grayscale', target_size=(img_height, img_width))
            if img is not None:
                img_array = img_to_array(img)
                images.append(img_array)
        except Exception as e:
            print(f"Error loading image {file_path}: {e}")
    images = np.array(images).astype('float32')
    images = (images - 127.5) / 127.5  # Normalize images to [-1, 1]
    return images

# Load images
lhsa_kanjur_images = load_images_from_folder(lhsa_kanjur_path, IMG_HEIGHT, IMG_WIDTH, CHANNELS)
computer_font_images = load_images_from_folder(computer_font_path, IMG_HEIGHT, IMG_WIDTH, CHANNELS)

# Split the data into training and validation sets
train_lhsa_kanjur, val_lhsa_kanjur, train_computer_font, val_computer_font = train_test_split(
    lhsa_kanjur_images, computer_font_images, test_size=0.2, random_state=42)

def create_dataset(input_images, target_images, batch_size=1):
    dataset = tf.data.Dataset.from_tensor_slices((input_images, target_images))
    dataset = dataset.shuffle(buffer_size=len(input_images))
    dataset = dataset.batch(batch_size)
    return dataset

# Create TensorFlow datasets
batch_size = 1
train_dataset = create_dataset(train_computer_font, train_lhsa_kanjur, batch_size)
val_dataset = create_dataset(val_computer_font, val_lhsa_kanjur, batch_size)
# Out:
# 2024-07-02 04:31:04.100744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22283 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:82:00.0, compute capability: 8.9

# %%
# Residual Block
def residual_block(x, filters, kernel_size=(3, 3)):
    r = Conv2D(filters, kernel_size, padding='same')(x)
    r = BatchNormalization()(r)
    r = ReLU()(r)
    r = Conv2D(filters, kernel_size, padding='same')(r)
    r = BatchNormalization()(r)
    r = Add()([r, x])
    return r

# Generator with reduced features in latent space (2x32)
def build_generator(input_shape):
    inputs = Input(input_shape)  # (256, 8192, 1)
    # Encoder
    e1 = Conv2D(32, (4, 4), strides=2, padding='same')(inputs)  # (128, 4096, 32)
    e2 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(64, (4, 4), strides=2, padding='same')(e1)))  # (64, 2048, 64)
    e3 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(128, (4, 4), strides=2, padding='same')(e2)))  # (32, 1024, 128)
    e4 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(256, (4, 4), strides=2, padding='same')(e3)))  # (16, 512, 256)
    e5 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(512, (4, 4), strides=2, padding='same')(e4)))  # (8, 256, 512)
    e6 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(1024, (4, 4), strides=2, padding='same')(e5)))  # (4, 128, 1024)
    e7 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(2048, (4, 4), strides=2, padding='same')(e6)))  # (2, 64, 2048)
    
    # Adding Residual Blocks to the Latent Space
    r = residual_block(e7, 2048)  # (2, 64, 2048)
    r = residual_block(r, 2048)  # (2, 64, 2048)
    
    # Decoder with additional layers and skip connections
    d1 = ReLU()(BatchNormalization()(Conv2DTranspose(1024, (4, 4), strides=2, padding='same')(r)))  # (4, 128, 1024)
    d1 = Concatenate()([d1, e6])  # (4, 128, 2048)
    d1 = residual_block(d1, 2048)  # (4, 128, 2048)
    
    d2 = ReLU()(BatchNormalization()(Conv2DTranspose(512, (4, 4), strides=2, padding='same')(d1)))  # (8, 256, 512)
    d2 = Concatenate()([d2, e5])  # (8, 256, 1024)
    d2 = residual_block(d2, 1024)  # (8, 256, 1024)
    
    d3 = ReLU()(BatchNormalization()(Conv2DTranspose(256, (4, 4), strides=2, padding='same')(d2)))  # (16, 512, 256)
    d3 = Concatenate()([d3, e4])  # (16, 512, 512)
    d3 = residual_block(d3, 512)  # (16, 512, 512)
    
    d4 = ReLU()(BatchNormalization()(Conv2DTranspose(128, (4, 4), strides=2, padding='same')(d3)))  # (32, 1024, 128)
    d4 = Concatenate()([d4, e3])  # (32, 1024, 256)
    d4 = residual_block(d4, 256)  # (32, 1024, 256)
    
    d5 = ReLU()(BatchNormalization()(Conv2DTranspose(64, (4, 4), strides=2, padding='same')(d4)))  # (64, 2048, 64)
    d5 = Concatenate()([d5, e2])  # (64, 2048, 128)
    d5 = residual_block(d5, 128)  # (64, 2048, 128)

    d6 = ReLU()(BatchNormalization()(Conv2DTranspose(32, (4, 4), strides=2, padding='same')(d5)))  # (128, 4096, 32)
    d6 = Concatenate()([d6, e1])  # (128, 4096, 64)
    d6 = residual_block(d6, 64)  # (128, 4096, 64)
    
    d7 = Conv2DTranspose(1, (4, 4), strides=2, padding='same', activation='tanh')(d6)  # (256, 8192, 1)
    
    return Model(inputs, d7)

# %%
# Discriminator with added complexity
def build_discriminator(input_shape):
    inputs = Input(input_shape)  # (256, 8192, 1)
    target = Input(input_shape)  # (256, 8192, 1)
    combined = Concatenate()([inputs, target])  # (256, 8192, 2)
    
    d1 = LeakyReLU(alpha=0.2)(Conv2D(64, (4, 4), strides=2, padding='same')(combined))  # (128, 4096, 64)
    d2 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(128, (4, 4), strides=2, padding='same')(d1)))  # (64, 2048, 128)
    d3 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(256, (4, 4), strides=2, padding='same')(d2)))  # (32, 1024, 256)
    d4 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(512, (4, 4), strides=2, padding='same')(d3)))  # (16, 512, 512)
    d5 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(1024, (4, 4), strides=2, padding='same')(d4)))  # (8, 256, 1024)
    d6 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(2048, (4, 4), strides=2, padding='same')(d5)))  # (4, 128, 2048)
    d7 = LeakyReLU(alpha=0.2)(BatchNormalization()(Conv2D(4096, (4, 4), strides=2, padding='same')(d6)))  # (2, 64, 4096)
    
    d8 = Conv2D(1, (4, 4), strides=1, padding='same')(d7)  # (2, 64, 1)
    
    return Model([inputs, target], d8)

# %%
class Pix2Pix(Model):
    def __init__(self, generator, discriminator, lambda_value=100):  # You can adjust lambda_value here
        super(Pix2Pix, self).__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.lambda_value = lambda_value
        self.generator_loss_tracker = tf.keras.metrics.Mean(name="generator_loss")
        self.discriminator_loss_tracker = tf.keras.metrics.Mean(name="discriminator_loss")

    def compile(self, generator_optimizer, discriminator_optimizer, gen_loss_fn, disc_loss_fn, **kwargs):
        super(Pix2Pix, self).compile(**kwargs)
        self.generator_optimizer = generator_optimizer
        self.discriminator_optimizer = discriminator_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn

    @property
    def metrics(self):
        return [self.generator_loss_tracker, self.discriminator_loss_tracker]

    def train_step(self, data):
        input_image, target = data

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            fake_image = self.generator(input_image, training=True)

            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_fake_output = self.discriminator([input_image, fake_image], training=True)

            gen_gan_loss = self.gen_loss_fn(tf.ones_like(disc_fake_output), disc_fake_output)
            gen_l1_loss = tf.reduce_mean(tf.abs(target - fake_image))
            gen_total_loss = gen_gan_loss + (self.lambda_value * gen_l1_loss)

            disc_real_loss = self.disc_loss_fn(tf.ones_like(disc_real_output), disc_real_output)
            disc_fake_loss = self.disc_loss_fn(tf.zeros_like(disc_fake_output), disc_fake_output)
            disc_total_loss = disc_real_loss + disc_fake_loss

        generator_gradients = gen_tape.gradient(gen_total_loss, self.generator.trainable_variables)
        discriminator_gradients = disc_tape.gradient(disc_total_loss, self.discriminator.trainable_variables)

        self.generator_optimizer.apply_gradients(zip(generator_gradients, self.generator.trainable_variables))
        self.discriminator_optimizer.apply_gradients(zip(discriminator_gradients, self.discriminator.trainable_variables))

        self.generator_loss_tracker.update_state(gen_total_loss)
        self.discriminator_loss_tracker.update_state(disc_total_loss)

        return {"generator_loss": self.generator_loss_tracker.result(), "discriminator_loss": self.discriminator_loss_tracker.result()}

    def test_step(self, data):
        input_image, target = data
        fake_image = self.generator(input_image, training=False)

        disc_real_output = self.discriminator([input_image, target], training=False)
        disc_fake_output = self.discriminator([input_image, fake_image], training=False)

        gen_gan_loss = self.gen_loss_fn(tf.ones_like(disc_fake_output), disc_fake_output)
        gen_l1_loss = tf.reduce_mean(tf.abs(target - fake_image))
        gen_total_loss = gen_gan_loss + (self.lambda_value * gen_l1_loss)

        disc_real_loss = self.disc_loss_fn(tf.ones_like(disc_real_output), disc_real_output)
        disc_fake_loss = self.disc_loss_fn(tf.zeros_like(disc_fake_output), disc_fake_output)
        disc_total_loss = disc_real_loss + disc_fake_loss

        return {"generator_loss": gen_total_loss, "discriminator_loss": disc_total_loss}

# %%
# Instantiate the Pix2Pix model
input_shape = (256, 8192, 1)
generator = build_generator(input_shape)
discriminator = build_discriminator(input_shape)

# Define optimizers
generator_optimizer = Adam(2e-4, beta_1=0.5)
discriminator_optimizer = Adam(2e-4, beta_1=0.5)

# Instantiate and compile the Pix2Pix model
pix2pix_model = Pix2Pix(generator, discriminator, lambda_value=100)

pix2pix_model.compile(
    generator_optimizer=generator_optimizer,
    discriminator_optimizer=discriminator_optimizer,
    gen_loss_fn=MeanSquaredError(),
    disc_loss_fn=MeanSquaredError()
)

# %%
# Set epochs
EPOCHS = 10

# Train the model
history = pix2pix_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset
)
# Out:
# Epoch 1/10
# 2024-07-02 04:31:45.556951: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 80.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.557009: W tensorflow/core/kernels/gpu_utils.cc:54] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2024-07-02 04:31:45.578379: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2024-07-02 04:31:45.691923: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 88.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.692005: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 88.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.692406: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.707482: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.707561: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.707579: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.707596: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.709158: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.709187: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-02 04:31:45.796121: W tensorflow/core/kernels/conv_ops_gpu.cc:322] None of the algorithms provided by cuDNN frontend heuristics worked; trying fallback algorithms.  Conv: batch: 1
# in_depths: 32
# out_depths: 64
# in: 128
# in: 4096
# data_format: 1
# filter: 4
# filter: 4
# filter: 32
# dilation: 1
# dilation: 1
# stride: 2
# stride: 2
# padding: 1
# padding: 1
# dtype: DT_FLOAT
# group_count: 1
# device_identifier: "sm_8.9 with 25386352640B RAM, 128 cores, 2625000KHz clock, 10501000KHz mem clock, 75497472B L2$"
# version: 3
#
# 2024-07-02 04:31:45.797914: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at conv_ops_impl.h:1199 : NOT_FOUND: No algorithm worked!  Error messages:
#   Profiling failure on CUDNN engine eng1{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16779264 bytes.
#   Profiling failure on CUDNN engine eng28{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777216 bytes.
#   Profiling failure on CUDNN engine eng0{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777216 bytes.
#   Profiling failure on CUDNN engine eng4{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 26525696 bytes.
# 2024-07-02 04:31:55.557204: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 128.00MiB (rounded to 134217728)requested by op model_1/conv2d_23/Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-07-02 04:31:55.557295: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-07-02 04:31:55.557327: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 141, Chunks in use: 141. 35.2KiB allocated for chunks. 35.2KiB in use in bin. 13.8KiB client-requested in use in bin.
# 2024-07-02 04:31:55.557340: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 56, Chunks in use: 55. 28.5KiB allocated for chunks. 27.8KiB in use in bin. 27.5KiB client-requested in use in bin.
# 2024-07-02 04:31:55.557351: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 56, Chunks in use: 56. 56.5KiB allocated for chunks. 56.5KiB in use in bin. 56.0KiB client-requested in use in bin.
# 2024-07-02 04:31:55.557363: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 58, Chunks in use: 58. 116.0KiB allocated for chunks. 116.0KiB in use in bin. 116.0KiB client-requested in use in bin.
# 2024-07-02 04:31:55.557374: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 58, Chunks in use: 58. 238.5KiB allocated for chunks. 238.5KiB in use in bin. 232.0KiB client-requested in use in bin.
# 2024-07-02 04:31:55.557385: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 91, Chunks in use: 91. 729.5KiB allocated for chunks. 729.5KiB in use in bin. 728.0KiB client-requested in use in bin.
# 2024-07-02 04:31:55.557396: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 11, Chunks in use: 11. 177.2KiB allocated for chunks. 177.2KiB in use in bin. 176.0KiB client-requested in use in bin.
# 2024-07-02 04:31:55.557407: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-02 04:31:55.557416: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-02 04:31:55.557427: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 8, Chunks in use: 8. 1.19MiB allocated for chunks. 1.19MiB in use in bin. 1.08MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557438: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 7, Chunks in use: 7. 1.77MiB allocated for chunks. 1.77MiB in use in bin. 1.64MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557448: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 12, Chunks in use: 12. 6.75MiB allocated for chunks. 6.75MiB in use in bin. 6.38MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557458: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 3, Chunks in use: 3. 4.17MiB allocated for chunks. 4.17MiB in use in bin. 3.00MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557470: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 11, Chunks in use: 11. 23.69MiB allocated for chunks. 23.69MiB in use in bin. 23.25MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557481: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 4, Chunks in use: 4. 18.00MiB allocated for chunks. 18.00MiB in use in bin. 14.25MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557492: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 14, Chunks in use: 14. 122.00MiB allocated for chunks. 122.00MiB in use in bin. 118.00MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557503: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 5, Chunks in use: 4. 80.00MiB allocated for chunks. 64.00MiB in use in bin. 64.00MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557514: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 13, Chunks in use: 12. 456.76MiB allocated for chunks. 408.00MiB in use in bin. 408.00MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557528: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 4, Chunks in use: 4. 256.00MiB allocated for chunks. 256.00MiB in use in bin. 256.00MiB client-requested in use in bin.
# 2024-07-02 04:31:55.557539: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 27, Chunks in use: 27. 3.69GiB allocated for chunks. 3.69GiB in use in bin. 3.66GiB client-requested in use in bin.
# 2024-07-02 04:31:55.557550: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 7, Chunks in use: 7. 17.12GiB allocated for chunks. 17.12GiB in use in bin. 17.12GiB client-requested in use in bin.
# 2024-07-02 04:31:55.557561: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 128.00MiB was 128.00MiB, Chunk State:
# 2024-07-02 04:31:55.557569: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 23366139904
# 2024-07-02 04:31:55.557580: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdbfa000000 of size 6710886400 next 1
# 2024-07-02 04:31:55.557589: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdd8a000000 of size 1280 next 2
# 2024-07-02 04:31:55.557598: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdd8a000500 of size 6710886400 next 3
# 2024-07-02 04:31:55.557605: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdf1a000500 of size 256 next 4
# 2024-07-02 04:31:55.557613: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdf1a000600 of size 256 next 5
# 2024-07-02 04:31:55.557621: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdf1a000700 of size 256 next 6
# 2024-07-02 04:31:55.557628: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdf1a000800 of size 256 next 7
# 2024-07-02 04:31:55.557637: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdf1a000900 of size 1677721600 next 8
# 2024-07-02 04:31:55.557645: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdf7e000900 of size 1677721600 next 9
# 2024-07-02 04:31:55.557653: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2000900 of size 256 next 10
# 2024-07-02 04:31:55.557660: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2000a00 of size 256 next 11
# 2024-07-02 04:31:55.557667: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2000b00 of size 256 next 12
# 2024-07-02 04:31:55.557675: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2000c00 of size 256 next 14
# 2024-07-02 04:31:55.557682: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2000d00 of size 256 next 15
# 2024-07-02 04:31:55.557689: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2000e00 of size 256 next 13
# 2024-07-02 04:31:55.557697: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2000f00 of size 256 next 16
# 2024-07-02 04:31:55.557704: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001000 of size 256 next 21
# 2024-07-02 04:31:55.557711: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001100 of size 256 next 19
# 2024-07-02 04:31:55.557719: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001200 of size 256 next 20
# 2024-07-02 04:31:55.557726: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001300 of size 256 next 24
# 2024-07-02 04:31:55.557734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001400 of size 256 next 25
# 2024-07-02 04:31:55.557741: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001500 of size 256 next 26
# 2024-07-02 04:31:55.557748: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001600 of size 256 next 27
# 2024-07-02 04:31:55.557757: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001700 of size 256 next 28
# 2024-07-02 04:31:55.557765: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001800 of size 512 next 31
# 2024-07-02 04:31:55.557773: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001a00 of size 512 next 29
# 2024-07-02 04:31:55.557780: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001c00 of size 768 next 17
# 2024-07-02 04:31:55.557788: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2001f00 of size 2048 next 18
# 2024-07-02 04:31:55.557796: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2002700 of size 512 next 30
# 2024-07-02 04:31:55.557803: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2002900 of size 512 next 34
# 2024-07-02 04:31:55.557810: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2002b00 of size 256 next 35
# 2024-07-02 04:31:55.557818: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2002c00 of size 256 next 36
# 2024-07-02 04:31:55.557825: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2002d00 of size 1024 next 39
# 2024-07-02 04:31:55.557833: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2003100 of size 1024 next 37
# 2024-07-02 04:31:55.557840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2003500 of size 1024 next 38
# 2024-07-02 04:31:55.557847: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2003900 of size 1024 next 42
# 2024-07-02 04:31:55.557855: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2003d00 of size 1024 next 43
# 2024-07-02 04:31:55.557862: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2004100 of size 256 next 44
# 2024-07-02 04:31:55.557869: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2004200 of size 256 next 45
# 2024-07-02 04:31:55.557877: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2004300 of size 2048 next 48
# 2024-07-02 04:31:55.557885: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2004b00 of size 2048 next 46
# 2024-07-02 04:31:55.557892: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2005300 of size 2048 next 47
# 2024-07-02 04:31:55.557899: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2005b00 of size 2048 next 51
# 2024-07-02 04:31:55.557907: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2006300 of size 2048 next 52
# 2024-07-02 04:31:55.557915: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2006b00 of size 256 next 53
# 2024-07-02 04:31:55.557922: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2006c00 of size 256 next 54
# 2024-07-02 04:31:55.557930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2006d00 of size 4096 next 57
# 2024-07-02 04:31:55.557937: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2007d00 of size 4096 next 55
# 2024-07-02 04:31:55.557944: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2008d00 of size 4096 next 56
# 2024-07-02 04:31:55.557952: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2009d00 of size 4096 next 60
# 2024-07-02 04:31:55.557959: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe200ad00 of size 4096 next 61
# 2024-07-02 04:31:55.557967: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe200bd00 of size 256 next 62
# 2024-07-02 04:31:55.557974: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe
: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2078900 of size 2048 next 120
# 2024-07-02 04:31:55.558375: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2079100 of size 2048 next 122
# 2024-07-02 04:31:55.558383: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2079900 of size 2048 next 123
# 2024-07-02 04:31:55.558392: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207a100 of size 256 next 124
# 2024-07-02 04:31:55.558400: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207a200 of size 256 next 125
# 2024-07-02 04:31:55.558407: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207a300 of size 4096 next 126
# 2024-07-02 04:31:55.558416: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207b300 of size 4096 next 127
# 2024-07-02 04:31:55.558423: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207c300 of size 4096 next 129
# 2024-07-02 04:31:55.558431: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207d300 of size 4096 next 130
# 2024-07-02 04:31:55.558439: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207e300 of size 4096 next 131
# 2024-07-02 04:31:55.558446: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe207f300 of size 4096 next 132
# 2024-07-02 04:31:55.558454: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2080300 of size 4096 next 133
# 2024-07-02 04:31:55.558461: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2081300 of size 4096 next 135
# 2024-07-02 04:31:55.558468: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2082300 of size 4096 next 136
# 2024-07-02 04:31:55.558476: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2083300 of size 4096 next 137
# 2024-07-02 04:31:55.558483: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2084300 of size 256 next 138
# 2024-07-02 04:31:55.558490: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2084400 of size 256 next 139
# 2024-07-02 04:31:55.558498: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2084500 of size 1024 next 140
# 2024-07-02 04:31:55.558505: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2084900 of size 1024 next 141
# 2024-07-02 04:31:55.558512: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2084d00 of size 1024 next 144
# 2024-07-02 04:31:55.558520: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2085100 of size 1024 next 145
# 2024-07-02 04:31:55.558527: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2085500 of size 1024 next 146
# 2024-07-02 04:31:55.558534: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2085900 of size 256 next 147
# 2024-07-02 04:31:55.558542: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2085a00 of size 256 next 148
# 2024-07-02 04:31:55.558549: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2085b00 of size 2048 next 149
# 2024-07-02 04:31:55.558556: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2086300 of size 2048 next 150
# 2024-07-02 04:31:55.558563: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2086b00 of size 2048 next 152
# 2024-07-02 04:31:55.558571: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2087300 of size 2048 next 153
# 2024-07-02 04:31:55.558579: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2087b00 of size 2048 next 154
# 2024-07-02 04:31:55.558587: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2088300 of size 2048 next 155
# 2024-07-02 04:31:55.558594: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2088b00 of size 2048 next 156
# 2024-07-02 04:31:55.558601: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2089300 of size 2048 next 158
# 2024-07-02 04:31:55.558608: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe2089b00 of size 2048 next 159
# 2024-07-02 04:31:55.558616: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208a300 of size 2048 next 160
# 2024-07-02 04:31:55.558623: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208ab00 of size 256 next 161
# 2024-07-02 04:31:55.558630: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208ac00 of size 256 next 162
# 2024-07-02 04:31:55.558638: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208ad00 of size 512 next 163
# 2024-07-02 04:31:55.558645: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208af00 of size 512 next 164
# 2024-07-02 04:31:55.558652: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208b100 of size 512 next 167
# 2024-07-02 04:31:55.558659: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208b300 of size 512 next 168
# 2024-07-02 04:31:55.558667: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208b500 of size 512 next 169
# 2024-07-02 04:31:55.558674: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208b700 of size 256 next 170
# 2024-07-02 04:31:55.558681: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208b800 of size 256 next 171
# 2024-07-02 04:31:55.558689: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208b900 of size 1024 next 172
# 2024-07-02 04:31:55.558696: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208bd00 of size 1024 next 173
# 2024-07-02 04:31:55.558704: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208c100 of size 1024 next 175
# 2024-07-02 04:31:55.558711: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208c500 of size 1024 next 176
# 2024-07-02 04:31:55.558718: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208c900 of size 1024 next 177
# 2024-07-02 04:31:55.558725: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe208cd00 of size 1024 next 178
# 2024-07-02 04:31:55.558733: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fdfe
: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2555904 totalling 2.44MiB
# 2024-07-02 04:31:55.562281: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 4194304 totalling 12.00MiB
# 2024-07-02 04:31:55.562290: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6291456 totalling 6.00MiB
# 2024-07-02 04:31:55.562298: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 8388608 totalling 56.00MiB
# 2024-07-02 04:31:55.562307: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 9437184 totalling 54.00MiB
# 2024-07-02 04:31:55.562318: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 12582912 totalling 12.00MiB
# 2024-07-02 04:31:55.562327: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 16777216 totalling 64.00MiB
# 2024-07-02 04:31:55.562336: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 33554432 totalling 192.00MiB
# 2024-07-02 04:31:55.562344: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 37748736 totalling 216.00MiB
# 2024-07-02 04:31:55.562353: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 67108864 totalling 256.00MiB
# 2024-07-02 04:31:55.562361: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 8 Chunks of size 134217728 totalling 1.00GiB
# 2024-07-02 04:31:55.562372: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 18 Chunks of size 150994944 totalling 2.53GiB
# 2024-07-02 04:31:55.562381: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 167772160 totalling 160.00MiB
# 2024-07-02 04:31:55.562390: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 536870912 totalling 1.50GiB
# 2024-07-02 04:31:55.562398: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 1677721600 totalling 3.12GiB
# 2024-07-02 04:31:55.562413: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 6710886400 totalling 12.50GiB
# 2024-07-02 04:31:55.562422: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 21.70GiB
# 2024-07-02 04:31:55.562431: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 23366139904 memory_limit_: 23366139904 available bytes: 0 curr_region_allocation_bytes_: 46732279808
# 2024-07-02 04:31:55.562445: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     23366139904
# InUse:                     23298227712
# MaxInUse:                  23349492992
# NumAllocs:                         814
# MaxAllocSize:               6710886400
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-07-02 04:31:55.562479: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] ****************************************************************************************************
# 2024-07-02 04:31:55.562515: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at conv_ops_impl.h:679 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1,64,128,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[8], line 5
#       2 EPOCHS = 10
#       4 # Train the model
# ----> 5 history = pix2pix_model.fit(
#       6     train_dataset,
#       7     epochs=EPOCHS,
#       8     validation_data=val_dataset
#       9 )
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node model/conv2d_1/Conv2D defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 1077, in launch_instance
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 529, in dispatch_queue
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 518, in process_one
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 424, in dispatch_shell
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 766, in execute_request
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#
#   File "/tmp/ipykernel_1246/764417131.py", line 5, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/tmp/ipykernel_1246/91280139.py", line 25, in train_step
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py", line 290, in call
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py", line 262, in convolution_op
#
# No algorithm worked!  Error messages:
#   Profiling failure on CUDNN engine eng1{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16779264 bytes.
#   Profiling failure on CUDNN engine eng28{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777216 bytes.
#   Profiling failure on CUDNN engine eng0{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777216 bytes.
#   Profiling failure on CUDNN engine eng4{}: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 26525696 bytes.
# 	 [[{{node model/conv2d_1/Conv2D}}]] [Op:__inference_train_function_18679]

# %%
import matplotlib.pyplot as plt

def generate_and_display_images(model, test_input, target, index):
    prediction = model(test_input, training=False)
    plt.figure(figsize=(15, 45))  # Increase the figure size to ensure high quality and images on separate lines
    
    display_list = [test_input[0], target[0], prediction[0]]
    title = ['Input Image', 'Ground Truth', 'Predicted Image']
    
    for i in range(3):
        plt.subplot(3, 1, i + 1)  # Change the layout to 3 rows, 1 column
        plt.title(title[i])
        plt.imshow(display_list[i] * 0.5 + 0.5, cmap='gray')  # Rescale to [0, 1] for visualization
        plt.axis('off')
    plt.show()

def evaluate_and_visualize(model, val_dataset, num_images=1):  # Set default to 1 to print only one set of images
    for i, (input_image, target) in enumerate(val_dataset.take(num_images)):
        generate_and_display_images(model.generator, input_image, target, i)

# Visualize the results on examples from the validation dataset
evaluate_and_visualize(pix2pix_model, val_dataset, num_images=1)  # Set to 1 to print only one set of images
