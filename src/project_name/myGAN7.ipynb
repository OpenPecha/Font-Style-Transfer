# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
# Define data directories
img1_data_dir = '/Users/norbujamling/Desktop/mydatanew/copied_images'
img2_data_dir = '/Users/norbujamling/Desktop/mydatanew/merged_images'

# %%
# Function to load images from directory
def load_images_from_dir(directory):
    images = []
    for filename in os.listdir(directory):
        if filename.endswith(".png"):
            img = tf.keras.preprocessing.image.load_img(
                os.path.join(directory, filename), 
                target_size=(28, 28), 
                color_mode='grayscale'
            )
            img = tf.keras.preprocessing.image.img_to_array(img)
            img = img.astype('float32') / 255.0  # Normalize pixel values
            images.append(img)
    return np.array(images)

# %%
# Load images from directories
img1_data = load_images_from_dir(img1_data_dir)
img2_data = load_images_from_dir(img2_data_dir)

# %%
# Get subset of data from img2_data
img1_data = img1_data
img2_data_subset = img2_data  # Change the number to get a different subset

# %%
# Print shapes
print("Shape of img1_data:", img1_data.shape)
print("Shape of img2_data_subset:", img2_data_subset.shape)

# Display a sample image from img1_data
plt.figure(figsize=(4, 4))
plt.imshow(img1_data[0].reshape(28, 28), cmap='gray')
plt.axis('off')
plt.title('Sample Image from img1_data')
plt.show()

# Display a sample image from img2_data_subset
plt.figure(figsize=(4, 4))
plt.imshow(img2_data_subset[0].reshape(28, 28), cmap='gray')
plt.axis('off')
plt.title('Sample Image from img2_data_subset')
plt.show()
# Out:
# Shape of img1_data: (19800, 28, 28, 1)
# Shape of img2_data_subset: (19800, 28, 28, 1)

# %%
input_shape=(28,28,1)

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Input(shape=input_shape))
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))  
    model.add(layers.Dense(28*28*1, activation='sigmoid'))
    model.add(layers.Reshape((28, 28, 1)))
    return model

# %%
generator = make_generator_model()
generator.summary()
# Out:
# Model: "sequential_323"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_168 (Flatten)           │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_213 (Dense)               │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_214 (Dense)               │ (None, 784)            │       101,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_20 (Reshape)            │ (None, 28, 28, 1)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 201,616 (787.56 KB)
#  Trainable params: 201,616 (787.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define discriminator model
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Input(shape=input_shape))
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))  
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
discriminator = make_discriminator_model()
discriminator.summary()
# Out:
# Model: "sequential_324"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_169 (Flatten)           │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_215 (Dense)               │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_216 (Dense)               │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,609 (393.00 KB)
#  Trainable params: 100,609 (393.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
class CycleGAN(tf.keras.Model):
    def __init__(self, generator_g, generator_f, discriminator_x, discriminator_y):
        super(CycleGAN, self).__init__()
        self.generator_g = generator_g
        self.generator_f = generator_f
        self.discriminator_x = discriminator_x
        self.discriminator_y = discriminator_y

    def compile(self, gen_g_optimizer, gen_f_optimizer, disc_x_optimizer, disc_y_optimizer, cycle_loss_fn):
        super(CycleGAN, self).compile()
        self.gen_g_optimizer = gen_g_optimizer
        self.gen_f_optimizer = gen_f_optimizer
        self.disc_x_optimizer = disc_x_optimizer
        self.disc_y_optimizer = disc_y_optimizer
        self.cycle_loss_fn = cycle_loss_fn

    def train_step(self, batch_data):
        real_x, real_y = batch_data

        with tf.GradientTape(persistent=True) as tape:
            # Generate fake images
            fake_y = self.generator_g(real_x, training=True)
            fake_x = self.generator_f(real_y, training=True)

            # Generate reconstructed images
            reconstructed_x = self.generator_f(fake_y, training=True)
            reconstructed_y = self.generator_g(fake_x, training=True)

            # Compute cycle consistency loss
            cycle_loss_x = self.cycle_loss_fn(real_x, reconstructed_x)
            cycle_loss_y = self.cycle_loss_fn(real_y, reconstructed_y)
            total_cycle_loss = cycle_loss_x + cycle_loss_y

            # Compute generator adversarial loss
            gen_g_adv_loss = -tf.reduce_mean(self.discriminator_y(fake_y))
            gen_f_adv_loss = -tf.reduce_mean(self.discriminator_x(fake_x))
            total_gen_adv_loss = gen_g_adv_loss + gen_f_adv_loss

            # Total generator loss
            total_gen_loss = total_gen_adv_loss + total_cycle_loss

            # Compute discriminator adversarial loss
            disc_x_loss_real = tf.reduce_mean(tf.square(self.discriminator_x(real_x) - 1))
            disc_x_loss_fake = tf.reduce_mean(tf.square(self.discriminator_x(fake_x)))
            disc_x_loss = 0.5 * (disc_x_loss_real + disc_x_loss_fake)

            disc_y_loss_real = tf.reduce_mean(tf.square(self.discriminator_y(real_y) - 1))
            disc_y_loss_fake = tf.reduce_mean(tf.square(self.discriminator_y(fake_y)))
            disc_y_loss = 0.5 * (disc_y_loss_real + disc_y_loss_fake)

        # Compute gradients and update weights
        gen_g_gradients = tape.gradient(total_gen_loss, self.generator_g.trainable_variables)
        gen_f_gradients = tape.gradient(total_gen_loss, self.generator_f.trainable_variables)
        disc_x_gradients = tape.gradient(disc_x_loss, self.discriminator_x.trainable_variables)
        disc_y_gradients = tape.gradient(disc_y_loss, self.discriminator_y.trainable_variables)

        self.gen_g_optimizer.apply_gradients(zip(gen_g_gradients, self.generator_g.trainable_variables))
        self.gen_f_optimizer.apply_gradients(zip(gen_f_gradients, self.generator_f.trainable_variables))
        self.disc_x_optimizer.apply_gradients(zip(disc_x_gradients, self.discriminator_x.trainable_variables))
        self.disc_y_optimizer.apply_gradients(zip(disc_y_gradients, self.discriminator_y.trainable_variables))

        return {
            "total_gen_loss": total_gen_loss,
            "total_cycle_loss": total_cycle_loss,
            "total_gen_adv_loss": total_gen_adv_loss,
            "disc_x_loss": disc_x_loss,
            "disc_y_loss": disc_y_loss
        }

# %%
# Instantiate generator and discriminator models
generator_g = make_generator_model()
generator_f = make_generator_model()
discriminator_x = make_discriminator_model()
discriminator_y = make_discriminator_model()

# Compile CycleGAN model
cycle_gan_model = CycleGAN(generator_g, generator_f, discriminator_x, discriminator_y)
cycle_gan_model.compile(
    gen_g_optimizer=tf.keras.optimizers.Adam(5e-5, beta_1=0.5),
    gen_f_optimizer=tf.keras.optimizers.Adam(5e-5, beta_1=0.5),
    disc_x_optimizer=tf.keras.optimizers.Adam(5e-5, beta_1=0.5),
    disc_y_optimizer=tf.keras.optimizers.Adam(5e-5, beta_1=0.5),
    cycle_loss_fn=tf.keras.losses.Huber()
)

# %%
# Train the model
cycle_gan_model.fit(
    img1_data, img2_data_subset,
    epochs=100,
    batch_size=32
)
# Out:
# Epoch 1/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - disc_x_loss: 0.2959 - disc_y_loss: 0.2906 - total_cycle_loss: 0.1747 - total_gen_adv_loss: -1.2946 - total_gen_loss: -1.1199
# Epoch 2/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2488 - disc_y_loss: 0.2455 - total_cycle_loss: 0.1249 - total_gen_adv_loss: -1.0858 - total_gen_loss: -0.9609
# Epoch 3/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2513 - disc_y_loss: 0.2324 - total_cycle_loss: 0.0883 - total_gen_adv_loss: -1.0295 - total_gen_loss: -0.9412
# Epoch 4/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2498 - disc_y_loss: 0.2282 - total_cycle_loss: 0.0737 - total_gen_adv_loss: -1.0035 - total_gen_loss: -0.9298
# Epoch 5/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2494 - disc_y_loss: 0.2192 - total_cycle_loss: 0.0713 - total_gen_adv_loss: -0.9854 - total_gen_loss: -0.9141
# Epoch 6/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2493 - disc_y_loss: 0.2129 - total_cycle_loss: 0.0731 - total_gen_adv_loss: -0.9758 - total_gen_loss: -0.9027
# Epoch 7/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2488 - disc_y_loss: 0.1962 - total_cycle_loss: 0.0668 - total_gen_adv_loss: -0.9498 - total_gen_loss: -0.8830
# Epoch 8/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2495 - disc_y_loss: 0.1966 - total_cycle_loss: 0.0698 - total_gen_adv_loss: -0.9507 - total_gen_loss: -0.8809
# Epoch 9/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2500 - disc_y_loss: 0.2097 - total_cycle_loss: 0.0822 - total_gen_adv_loss: -0.9701 - total_gen_loss: -0.8878
# Epoch 10/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2487 - disc_y_loss: 0.2028 - total_cycle_loss: 0.0816 - total_gen_adv_loss: -0.9579 - total_gen_loss: -0.8763
# Epoch 11/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2491 - disc_y_loss: 0.1798 - total_cycle_loss: 0.0776 - total_gen_adv_loss: -0.9261 - total_gen_loss: -0.8485
# Epoch 12/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2479 - disc_y_loss: 0.1943 - total_cycle_loss: 0.0761 - total_gen_adv_loss: -0.9407 - total_gen_loss: -0.8646
# Epoch 13/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2490 - disc_y_loss: 0.1977 - total_cycle_loss: 0.0833 - total_gen_adv_loss: -0.9462 - total_gen_loss: -0.8630
# Epoch 14/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - disc_x_loss: 0.2483 - disc_y_loss: 0.1777 - total_cycle_loss: 0.0862 - total_gen_adv_loss: -0.9224 - total_gen_loss: -0.8362
# Epoch 15/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2483 - disc_y_loss: 0.1642 - total_cycle_loss: 0.0828 - total_gen_adv_loss: -0.9030 - total_gen_loss: -0.8202
# Epoch 16/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2490 - disc_y_loss: 0.1663 - total_cycle_loss: 0.0901 - total_gen_adv_loss: -0.9076 - total_gen_loss: -0.8175
# Epoch 17/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2488 - disc_y_loss: 0.1678 - total_cycle_loss: 0.0881 - total_gen_adv_loss: -0.9074 - total_gen_loss: -0.8193
# Epoch 18/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2483 - disc_y_loss: 0.1473 - total_cycle_loss: 0.0825 - total_gen_adv_loss: -0.8768 - total_gen_loss: -0.7942
# Epoch 19/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2488 - disc_y_loss: 0.1307 - total_cycle_loss: 0.0802 - total_gen_adv_loss: -0.8547 - total_gen_loss: -0.7745
# Epoch 20/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2479 - disc_y_loss: 0.1335 - total_cycle_loss: 0.0856 - total_gen_adv_loss: -0.8566 - total_gen_loss: -0.7710
# Epoch 21/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2490 - disc_y_loss: 0.1225 - total_cycle_loss: 0.0815 - total_gen_adv_loss: -0.8386 - total_gen_loss: -0.7571
# Epoch 22/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2482 - disc_y_loss: 0.1237 - total_cycle_loss: 0.0913 - total_gen_adv_loss: -0.8437 - total_gen_loss: -0.7524
# Epoch 23/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2481 - disc_y_loss: 0.1047 - total_cycle_loss: 0.0887 - total_gen_adv_loss: -0.8137 - total_gen_loss: -0.7250
# Epoch 24/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2481 - disc_y_loss: 0.0966 - total_cycle_loss: 0.0826 - total_gen_adv_loss: -0.7991 - total_gen_loss: -0.7165
# Epoch 25/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2483 - disc_y_loss: 0.1130 - total_cycle_loss: 0.0914 - total_gen_adv_loss: -0.8264 - total_gen_loss: -0.7351
# Epoch 26/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2476 - disc_y_loss: 0.1276 - total_cycle_loss: 0.0985 - total_gen_adv_loss: -0.8455 - total_gen_loss: -0.7470
# Epoch 27/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2483 - disc_y_loss: 0.1005 - total_cycle_loss: 0.0989 - total_gen_adv_loss: -0.8091 - total_gen_loss: -0.7102
# Epoch 28/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2490 - disc_y_loss: 0.1062 - total_cycle_loss: 0.0971 - total_gen_adv_loss: -0.8141 - total_gen_loss: -0.7170
# Epoch 29/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2497 - disc_y_loss: 0.0970 - total_cycle_loss: 0.0912 - total_gen_adv_loss: -0.7999 - total_gen_loss: -0.7088
# Epoch 30/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2496 - disc_y_loss: 0.0892 - total_cycle_loss: 0.0953 - total_gen_adv_loss: -0.7855 - total_gen_loss: -0.6901
# Epoch 31/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2493 - disc_y_loss: 0.0879 - total_cycle_loss: 0.0963 - total_gen_adv_loss: -0.7855 - total_gen_loss: -0.6891
# Epoch 32/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2497 - disc_y_loss: 0.1017 - total_cycle_loss: 0.1059 - total_gen_adv_loss: -0.8081 - total_gen_loss: -0.7022
# Epoch 33/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2484 - disc_y_loss: 0.0951 - total_cycle_loss: 0.1198 - total_gen_adv_loss: -0.7970 - total_gen_loss: -0.6772
# Epoch 34/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2483 - disc_y_loss: 0.0966 - total_cycle_loss: 0.1147 - total_gen_adv_loss: -0.7992 - total_gen_loss: -0.6845
# Epoch 35/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2475 - disc_y_loss: 0.0985 - total_cycle_loss: 0.1093 - total_gen_adv_loss: -0.7997 - total_gen_loss: -0.6904
# Epoch 36/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2485 - disc_y_loss: 0.0830 - total_cycle_loss: 0.1014 - total_gen_adv_loss: -0.7750 - total_gen_loss: -0.6736
# Epoch 37/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2479 - disc_y_loss: 0.0834 - total_cycle_loss: 0.1022 - total_gen_adv_loss: -0.7640 - total_gen_loss: -0.6618
# Epoch 38/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2487 - disc_y_loss: 0.0557 - total_cycle_loss: 0.1010 - total_gen_adv_loss: -0.7243 - total_gen_loss: -0.6233
# Epoch 39/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2486 - disc_y_loss: 0.0820 - total_cycle_loss: 0.1137 - total_gen_adv_loss: -0.7712 - total_gen_loss: -0.6576
# Epoch 40/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2491 - disc_y_loss: 0.0770 - total_cycle_loss: 0.0968 - total_gen_adv_loss: -0.7546 - total_gen_loss: -0.6578
# Epoch 41/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2486 - disc_y_loss: 0.0579 - total_cycle_loss: 0.0925 - total_gen_adv_loss: -0.7217 - total_gen_loss: -0.6292
# Epoch 42/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2496 - disc_y_loss: 0.0544 - total_cycle_loss: 0.0928 - total_gen_adv_loss: -0.7151 - total_gen_loss: -0.6224
# Epoch 43/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2489 - disc_y_loss: 0.0461 - total_cycle_loss: 0.0997 - total_gen_adv_loss: -0.6991 - total_gen_loss: -0.5994
# Epoch 44/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2495 - disc_y_loss: 0.0521 - total_cycle_loss: 0.1066 - total_gen_adv_loss: -0.7070 - total_gen_loss: -0.6005
# Epoch 45/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2473 - disc_y_loss: 0.0491 - total_cycle_loss: 0.1001 - total_gen_adv_loss: -0.7044 - total_gen_loss: -0.6043
# Epoch 46/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2488 - disc_y_loss: 0.0601 - total_cycle_loss: 0.0894 - total_gen_adv_loss: -0.7193 - total_gen_loss: -0.6298
# Epoch 47/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2481 - disc_y_loss: 0.0575 - total_cycle_loss: 0.0895 - total_gen_adv_loss: -0.7166 - total_gen_loss: -0.6272
# Epoch 48/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2495 - disc_y_loss: 0.0481 - total_cycle_loss: 0.0941 - total_gen_adv_loss: -0.6988 - total_gen_loss: -0.6047
# Epoch 49/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2482 - disc_y_loss: 0.0551 - total_cycle_loss: 0.1051 - total_gen_adv_loss: -0.7141 - total_gen_loss: -0.6090
# Epoch 50/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2490 - disc_y_loss: 0.0557 - total_cycle_loss: 0.1022 - total_gen_adv_loss: -0.7153 - total_gen_loss: -0.6131
# Epoch 51/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2481 - disc_y_loss: 0.0555 - total_cycle_loss: 0.1067 - total_gen_adv_loss: -0.7168 - total_gen_loss: -0.6102
# Epoch 52/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - disc_x_loss: 0.2502 - disc_y_loss: 0.0616 - total_cycle_loss: 0.1102 - total_gen_adv_loss: -0.7253 - total_gen_loss: -0.6151
# Epoch 53/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2491 - disc_y_loss: 0.0466 - total_cycle_loss: 0.1114 - total_gen_adv_loss: -0.6971 - total_gen_loss: -0.5857
# Epoch 54/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2482 - disc_y_loss: 0.0573 - total_cycle_loss: 0.1084 - total_gen_adv_loss: -0.7172 - total_gen_loss: -0.6088
# Epoch 55/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2500 - disc_y_loss: 0.0108 - total_cycle_loss: 0.1499 - total_gen_adv_loss: -0.5974 - total_gen_loss: -0.4475
# Epoch 56/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2492 - disc_y_loss: 0.0666 - total_cycle_loss: 0.1215 - total_gen_adv_loss: -0.7230 - total_gen_loss: -0.6014
# Epoch 57/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2487 - disc_y_loss: 0.0559 - total_cycle_loss: 0.1135 - total_gen_adv_loss: -0.7086 - total_gen_loss: -0.5951
# Epoch 58/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2502 - disc_y_loss: 0.0681 - total_cycle_loss: 0.1105 - total_gen_adv_loss: -0.7337 - total_gen_loss: -0.6231
# Epoch 59/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2479 - disc_y_loss: 0.0735 - total_cycle_loss: 0.0991 - total_gen_adv_loss: -0.7355 - total_gen_loss: -0.6365
# Epoch 60/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2498 - disc_y_loss: 0.0452 - total_cycle_loss: 0.1039 - total_gen_adv_loss: -0.6904 - total_gen_loss: -0.5865
# Epoch 61/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2487 - disc_y_loss: 0.0639 - total_cycle_loss: 0.1114 - total_gen_adv_loss: -0.7208 - total_gen_loss: -0.6094
# Epoch 62/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2490 - disc_y_loss: 0.0560 - total_cycle_loss: 0.1183 - total_gen_adv_loss: -0.7133 - total_gen_loss: -0.5950
# Epoch 63/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2492 - disc_y_loss: 0.0551 - total_cycle_loss: 0.1174 - total_gen_adv_loss: -0.7108 - total_gen_loss: -0.5934
# Epoch 64/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2496 - disc_y_loss: 0.0710 - total_cycle_loss: 0.1267 - total_gen_adv_loss: -0.7390 - total_gen_loss: -0.6123
# Epoch 65/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2493 - disc_y_loss: 0.0798 - total_cycle_loss: 0.1300 - total_gen_adv_loss: -0.7451 - total_gen_loss: -0.6151
# Epoch 66/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2488 - disc_y_loss: 0.0480 - total_cycle_loss: 0.1464 - total_gen_adv_loss: -0.6889 - total_gen_loss: -0.5425
# Epoch 67/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2492 - disc_y_loss: 0.1192 - total_cycle_loss: 0.1370 - total_gen_adv_loss: -0.7950 - total_gen_loss: -0.6580
# Epoch 68/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2484 - disc_y_loss: 0.0673 - total_cycle_loss: 0.1086 - total_gen_adv_loss: -0.7235 - total_gen_loss: -0.6149
# Epoch 69/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2495 - disc_y_loss: 0.0758 - total_cycle_loss: 0.1108 - total_gen_adv_loss: -0.7360 - total_gen_loss: -0.6252
# Epoch 70/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2492 - disc_y_loss: 0.0437 - total_cycle_loss: 0.1112 - total_gen_adv_loss: -0.6818 - total_gen_loss: -0.5706
# Epoch 71/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2484 - disc_y_loss: 0.0639 - total_cycle_loss: 0.1001 - total_gen_adv_loss: -0.7042 - total_gen_loss: -0.6041
# Epoch 72/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2491 - disc_y_loss: 0.0404 - total_cycle_loss: 0.0975 - total_gen_adv_loss: -0.6717 - total_gen_loss: -0.5741
# Epoch 73/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2488 - disc_y_loss: 0.0524 - total_cycle_loss: 0.1112 - total_gen_adv_loss: -0.6901 - total_gen_loss: -0.5789
# Epoch 74/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2486 - disc_y_loss: 0.0717 - total_cycle_loss: 0.0916 - total_gen_adv_loss: -0.7188 - total_gen_loss: -0.6273
# Epoch 75/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2499 - disc_y_loss: 0.0533 - total_cycle_loss: 0.0883 - total_gen_adv_loss: -0.6947 - total_gen_loss: -0.6064
# Epoch 76/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2495 - disc_y_loss: 0.0444 - total_cycle_loss: 0.0997 - total_gen_adv_loss: -0.6747 - total_gen_loss: -0.5750
# Epoch 77/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2492 - disc_y_loss: 0.0318 - total_cycle_loss: 0.0975 - total_gen_adv_loss: -0.6528 - total_gen_loss: -0.5554
# Epoch 78/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2495 - disc_y_loss: 0.0296 - total_cycle_loss: 0.0925 - total_gen_adv_loss: -0.6495 - total_gen_loss: -0.5570
# Epoch 79/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2492 - disc_y_loss: 0.0188 - total_cycle_loss: 0.0986 - total_gen_adv_loss: -0.6144 - total_gen_loss: -0.5158
# Epoch 80/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2481 - disc_y_loss: 0.0360 - total_cycle_loss: 0.0982 - total_gen_adv_loss: -0.6493 - total_gen_loss: -0.5511
# Epoch 81/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2498 - disc_y_loss: 0.0246 - total_cycle_loss: 0.0854 - total_gen_adv_loss: -0.6356 - total_gen_loss: -0.5502
# Epoch 82/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2491 - disc_y_loss: 0.0505 - total_cycle_loss: 0.0875 - total_gen_adv_loss: -0.6859 - total_gen_loss: -0.5984
# Epoch 83/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2482 - disc_y_loss: 0.0565 - total_cycle_loss: 0.0959 - total_gen_adv_loss: -0.6894 - total_gen_loss: -0.5935
# Epoch 84/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2483 - disc_y_loss: 0.0466 - total_cycle_loss: 0.0945 - total_gen_adv_loss: -0.6776 - total_gen_loss: -0.5831
# Epoch 85/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2485 - disc_y_loss: 0.0470 - total_cycle_loss: 0.0992 - total_gen_adv_loss: -0.6772 - total_gen_loss: -0.5780
# Epoch 86/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2500 - disc_y_loss: 0.0553 - total_cycle_loss: 0.1046 - total_gen_adv_loss: -0.6882 - total_gen_loss: -0.5836
# Epoch 87/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2487 - disc_y_loss: 0.0629 - total_cycle_loss: 0.1073 - total_gen_adv_loss: -0.7105 - total_gen_loss: -0.6032
# Epoch 88/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2506 - disc_y_loss: 0.0807 - total_cycle_loss: 0.1090 - total_gen_adv_loss: -0.7396 - total_gen_loss: -0.6306
# Epoch 89/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2485 - disc_y_loss: 0.0654 - total_cycle_loss: 0.0957 - total_gen_adv_loss: -0.7131 - total_gen_loss: -0.6175
# Epoch 90/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2480 - disc_y_loss: 0.0835 - total_cycle_loss: 0.1036 - total_gen_adv_loss: -0.6980 - total_gen_loss: -0.5944
# Epoch 91/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2493 - disc_y_loss: 0.0727 - total_cycle_loss: 0.1029 - total_gen_adv_loss: -0.7215 - total_gen_loss: -0.6186
# Epoch 92/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2486 - disc_y_loss: 0.0498 - total_cycle_loss: 0.0994 - total_gen_adv_loss: -0.6839 - total_gen_loss: -0.5845
# Epoch 93/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2498 - disc_y_loss: 0.0514 - total_cycle_loss: 0.1074 - total_gen_adv_loss: -0.6910 - total_gen_loss: -0.5836
# Epoch 94/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2492 - disc_y_loss: 0.0778 - total_cycle_loss: 0.1016 - total_gen_adv_loss: -0.7236 - total_gen_loss: -0.6219
# Epoch 95/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2481 - disc_y_loss: 0.0482 - total_cycle_loss: 0.1063 - total_gen_adv_loss: -0.6830 - total_gen_loss: -0.5766
# Epoch 96/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2499 - disc_y_loss: 0.0571 - total_cycle_loss: 0.0979 - total_gen_adv_loss: -0.6977 - total_gen_loss: -0.5998
# Epoch 97/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2487 - disc_y_loss: 0.0479 - total_cycle_loss: 0.0950 - total_gen_adv_loss: -0.6776 - total_gen_loss: -0.5826
# Epoch 98/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2486 - disc_y_loss: 0.0546 - total_cycle_loss: 0.1046 - total_gen_adv_loss: -0.6851 - total_gen_loss: -0.5805
# Epoch 99/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2487 - disc_y_loss: 0.0625 - total_cycle_loss: 0.1028 - total_gen_adv_loss: -0.7053 - total_gen_loss: -0.6025
# Epoch 100/100
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - disc_x_loss: 0.2493 - disc_y_loss: 0.0170 - total_cycle_loss: 0.1264 - total_gen_adv_loss: -0.6150 - total_gen_loss: -0.4885

# %%
import matplotlib.pyplot as plt

# Check shapes
print("Shape of img1_data:", img1_data.shape)
print("Shape of img2_data_subset:", img2_data_subset.shape)

# Visualize images from img1_data
plt.figure(figsize=(10, 5))
for i in range(5):  # Plot the first 5 images
    plt.subplot(1, 5, i + 1)
    plt.imshow(img1_data[i])  # Assuming img1_data contains images in the correct format
    plt.axis('off')
    plt.title('Image {}'.format(i + 1))
plt.show()

# Visualize images from img2_data_subset
plt.figure(figsize=(10, 5))
for i in range(5):  # Plot the first 5 images
    plt.subplot(1, 5, i + 1)
    plt.imshow(img2_data_subset[i])  # Assuming img2_data_subset contains images in the correct format
    plt.axis('off')
    plt.title('Image {}'.format(i + 1))
plt.show()
# Out:
# Shape of img1_data: (19800, 28, 28, 1)
# Shape of img2_data_subset: (19800, 28, 28, 1)

# %%
# Generate images using the trained generator
generated_images = generator_g.predict(img1_data)
# Out:
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step

# %%
# Visualize the generated images
import matplotlib.pyplot as plt
plt.figure(figsize=(200,100))
for i in range(15):  # Visualize the first 5 generated images
    plt.subplot(1, 15, i + 1)
    plt.imshow(generated_images[i])  # Assuming generated_images is in the correct format
    plt.axis('off')
    plt.title('Generated Image {}'.format(i + 1))
plt.show()

# %%
# Assuming original_images contains the original images and generated_images contains the generated images
original_images = img1_data
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
for i in range(15):  # Visualize the first 15 original and generated image pairs
    plt.subplot(3, 15, i + 1)
    plt.imshow(original_images[i].reshape(28, 28), cmap='gray')  # Assuming the images are grayscale
    plt.axis('off')
    plt.title('Ori{}'.format(i + 1))

    plt.subplot(3, 15, i + 16)
    plt.imshow(generated_images[i].reshape(28, 28), cmap='gray')  # Assuming the images are grayscale
    plt.axis('off')
    plt.title('Gen{}'.format(i + 1))

plt.show()
